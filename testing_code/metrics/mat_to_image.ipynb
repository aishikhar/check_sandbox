# %%
from glob import glob 
import os
import cv2
import numpy as np
from scipy import io as sio
import matplotlib.pyplot as plt
from IPython.display import clear_output
import sys
data_dir = None
output_dir = None
model_path = None
img_ext = None
ambi_path = None

data_dir = '/home/dm1/shikhar/check_sandbox/testing_code/model_output_final' # Predicted without Ambigous Removal
output_dir = '/home/dm1/shikhar/check_sandbox/testing_code/overlay_output' # Staging - Overlay Predicted & Ambiguous
ambi_path = '/home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions'

#file_list = glob.glob('%s/*%s' % (data_dir, img_ext))
#file_list.sort() # ensure same order
#if(not file_list):
# print('No Images found in data_dir! Check script arg-paths') 
# Create Output Directory
#rm_n_mkdir(output_dir)       
# Expecting MoNuSAC's input data directory tree (Patient Name -> Image Name -> )

if not os.path.isdir(output_dir):
    os.makedirs(output_dir)
os.chdir(output_dir)

patients = glob(data_dir + '/*')
print(len(patients))

for patient_loc in patients:
    patient_name = patient_loc[len(data_dir)+1:]#Patient name
    print('Patient name: ',patient_name)
    
    ## To make patient's name directory in the destination folder
    try:
        os.mkdir(patient_name)
    except OSError:
        print ("\n Creation of the patient's directory %s failed" % patient_name,  flush=True)

    sub_images = glob(str(patient_loc) + '/*')
    for sub_image_loc in sub_images:
        sub_image_name = sub_image_loc[len(data_dir)+len(patient_name)+1:]        
        print('Sub image name: ',sub_image_name)
        
        ## To make sub_image directory under the patient's folder
        sub_image = './'+patient_name + sub_image_name #Destination path
        
        try:
            os.mkdir(sub_image)
            os.mkdir(sub_image + '/Epithelial')
            os.mkdir(sub_image + '/Lymphocyte')
            os.mkdir(sub_image + '/Macrophage')
            os.mkdir(sub_image + '/Neutrophil')
        except OSError:
            print ("\n Creation of the patient's directory %s failed" % sub_image)
        

        image_name = sub_image_loc
        print(sub_image_loc)
        e_flag = True
        l_flag = True
        m_flag = True
        n_flag = True
        try:
            e_image = sio.loadmat(sub_image_loc + '/Epithelial/mask.mat')['n_ary_mask']
        except Exception as e:
            print('No-mask')
            e_flag = False
        try:
            l = sio.loadmat(sub_image_loc + '/Lymphocyte/mask.mat')['n_ary_mask']
        except Exception as e:
            print('No-mask')
            l_flag = False
        try:    
            m = sio.loadmat(sub_image_loc + '/Macrophage/mask.mat')['n_ary_mask']
        except Exception as e:
            print('No-mask')
            m_flag = False
        try:
            n = sio.loadmat(sub_image_loc + '/Neutrophil/mask.mat')['n_ary_mask']
        except Exception as e:
            print('No-mask')
            n_flag = False
    
        # Read Ambiguous Region mask if any
        ambi_mask_final = None
        full_ambi_path = ambi_path + '/' + patient_name + '/' + sub_image_name + '/Ambiguous' 
        print('\tAmbi Path: ',full_ambi_path)
        ambi_masks = glob(full_ambi_path+'/*')
        if(ambi_masks):
            try:
                ambi_mask_final = cv2.imread(ambi_masks[0])
                #print('Ambiguous Mask Found: ',ambi_mask_final.shape)
            
                # START CHANGES 
                gray = cv2.cvtColor(ambi_mask_final, cv2.COLOR_BGR2GRAY)
                count, ambi = cv2.connectedComponents(gray)                
                
                # Show Overlay of Prediction & Ambi
                if(e_flag):
                    plt.imshow(e_image, 'gray', interpolation='none')
                    plt.imshow(ambi, 'Paired', interpolation='none', alpha=0.7)
                    plt.savefig(sub_image + '/Epithelial' + '/fig.png')
                if(l_flag):
                    plt.imshow(l, 'gray', interpolation='none')
                    plt.imshow(ambi, 'Paired', interpolation='none', alpha=0.7)
                    plt.savefig(sub_image + '/Lymphocyte' + '/fig.png')
                if(m_flag):
                    plt.imshow(m, 'gray', interpolation='none')
                    plt.imshow(ambi, 'Paired', interpolation='none', alpha=0.7)
                    plt.savefig(sub_image + '/Macrophage' + '/fig.png')
                if(n_flag):
                    plt.imshow(n, 'gray', interpolation='none')
                    plt.imshow(ambi, 'Paired', interpolation='none', alpha=0.7)
                    plt.savefig(sub_image + '/Neutrophil' + '/fig.png')
        
                '''#print('Prediction: ',np.unique(pred_inst))
                plt.imshow(pred_inst)
                plt.show()
                #print('Prediction Cleaned: ',np.unique(prediction_cleaned))
                plt.imshow(prediction_cleaned)
                plt.show()
                #print('Ambiguous: ',np.unique(ambi))
                plt.imshow(ambi)
                plt.show()'''
                #print('Removed are: ', set(list(np.unique(pred_inst))) - set(list(np.unique(prediction_cleaned))) )
                # ========
            except Exception as e:
                print(e)
        else:
            print('\n\t # No Ambiguous Masks for this image: ', full_ambi_path)
            if(e_flag):
                plt.imshow(e_image, 'gray', interpolation='none')
                plt.savefig(sub_image + '/Epithelial' + '/fig.png')
            if(l_flag):
                plt.imshow(l, 'gray', interpolation='none')
                plt.savefig(sub_image + '/Lymphocyte' + '/fig.png')
            if(m_flag):
                plt.imshow(m, 'gray', interpolation='none')
                plt.savefig(sub_image + '/Macrophage' + '/fig.png')
            if(n_flag):
                plt.imshow(n, 'gray', interpolation='none')
                plt.savefig(sub_image + '/Neutrophil' + '/fig.png')

'''        # Write Instance Maps based on their Classes/Labels to the folders
        for class_id in range(1,self.nr_types):
            separated_inst = pred_inst.copy()
            separated_inst[pred_inst_type[separated_inst-1]!=[class_id]] = 0
            # Create directory for each label
            label = class_id_mapping[class_id]
            sub_path = sub_image+'/'+label
            try:
                os.mkdir(sub_path)
            except OSError:
                print ("Creation of the directory %s failed" % label)
            else:
                print ("Successfully created the directory %s " % label)

            sio.savemat(sub_path +'/maskorempty.mat', 
                {'n_ary_mask'  :  separated_inst})'''
# Out:
# 25
# Patient name:  TCGA-EW-A6SB-01Z-00-DX1
# Sub image name:  /TCGA-EW-A6SB-01Z-00-DX1_001
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-EW-A6SB-01Z-00-DX1/TCGA-EW-A6SB-01Z-00-DX1_001
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-EW-A6SB-01Z-00-DX1//TCGA-EW-A6SB-01Z-00-DX1_001/Ambiguous
# Sub image name:  /TCGA-EW-A6SB-01Z-00-DX1_005
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-EW-A6SB-01Z-00-DX1/TCGA-EW-A6SB-01Z-00-DX1_005
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-DW-7963-01Z-00-DX1//TCGA-DW-7963-01Z-00-DX1_2/Ambiguous
#
# 	 # No Ambiguous Masks for this image:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-DW-7963-01Z-00-DX1//TCGA-DW-7963-01Z-00-DX1_2/Ambiguous
# Sub image name:  /TCGA-DW-7963-01Z-00-DX1_4
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-DW-7963-01Z-00-DX1/TCGA-DW-7963-01Z-00-DX1_4
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-DW-7963-01Z-00-DX1//TCGA-DW-7963-01Z-00-DX1_4/Ambiguous
#
# 	 # No Ambiguous Masks for this image:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-DW-7963-01Z-00-DX1//TCGA-DW-7963-01Z-00-DX1_4/Ambiguous
# Patient name:  TCGA-G9-6356-01Z-00-DX1
# Sub image name:  /TCGA-G9-6356-01Z-00-DX1_5
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-G9-6356-01Z-00-DX1/TCGA-G9-6356-01Z-00-DX1_5
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-G9-6356-01Z-00-DX1//TCGA-G9-6356-01Z-00-DX1_5/Ambiguous
# Sub image name:  /TCGA-G9-6356-01Z-00-DX1_1
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-G9-6356-01Z-00-DX1/TCGA-G9-6356-01Z-00-DX1_1
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-G9-6356-01Z-00-DX1//TCGA-G9-6356-01Z-00-DX1_1/Ambiguous
# Sub image name:  /TCGA-G9-6356-01Z-00-DX1_3
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-G9-6356-01Z-00-DX1/TCGA-G9-6356-01Z-00-DX1_3
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-G9-6356-01Z-00-DX1//TCGA-G9-6356-01Z-00-DX1_3/Ambiguous
# Sub image name:  /TCGA-G9-6356-01Z-00-DX1_6
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-G9-6356-01Z-00-DX1/TCGA-G9-6356-01Z-00-DX1_6
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-G9-6356-01Z-00-DX1//TCGA-G9-6356-01Z-00-DX1_6/Ambiguous
# Sub image name:  /TCGA-G9-6356-01Z-00-DX1_4
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-G9-6356-01Z-00-DX1/TCGA-G9-6356-01Z-00-DX1_4
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-G9-6356-01Z-00-DX1//TCGA-G9-6356-01Z-00-DX1_4/Ambiguous
# Patient name:  TCGA-50-6591-01Z-00-DX1
# Sub image name:  /TCGA-50-6591-01Z-00-DX1_001
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-50-6591-01Z-00-DX1/TCGA-50-6591-01Z-00-DX1_001
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-50-6591-01Z-00-DX1//TCGA-50-6591-01Z-00-DX1_001/Ambiguous
# Patient name:  TCGA-YL-A9WL-01Z-00-DX1
# Sub image name:  /TCGA-YL-A9WL-01Z-00-DX1_3
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-YL-A9WL-01Z-00-DX1/TCGA-YL-A9WL-01Z-00-DX1_3
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-YL-A9WL-01Z-00-DX1//TCGA-YL-A9WL-01Z-00-DX1_3/Ambiguous
# Sub image name:  /TCGA-YL-A9WL-01Z-00-DX1_1
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-YL-A9WL-01Z-00-DX1/TCGA-YL-A9WL-01Z-00-DX1_1
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-YL-A9WL-01Z-00-DX1//TCGA-YL-A9WL-01Z-00-DX1_1/Ambiguous
# Sub image name:  /TCGA-YL-A9WL-01Z-00-DX1_4
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-YL-A9WL-01Z-00-DX1/TCGA-YL-A9WL-01Z-00-DX1_4
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-YL-A9WL-01Z-00-DX1//TCGA-YL-A9WL-01Z-00-DX1_4/Ambiguous
# Sub image name:  /TCGA-YL-A9WL-01Z-00-DX1_2
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-YL-A9WL-01Z-00-DX1/TCGA-YL-A9WL-01Z-00-DX1_2
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-YL-A9WL-01Z-00-DX1//TCGA-YL-A9WL-01Z-00-DX1_2/Ambiguous
# Patient name:  TCGA-49-6743-01Z-00-DX2
# Sub image name:  /TCGA-49-6743-01Z-00-DX2_003
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-49-6743-01Z-00-DX2/TCGA-49-6743-01Z-00-DX2_003
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-49-6743-01Z-00-DX2//TCGA-49-6743-01Z-00-DX2_003/Ambiguous
# Sub image name:  /TCGA-49-6743-01Z-00-DX2_001
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-49-6743-01Z-00-DX2/TCGA-49-6743-01Z-00-DX2_001
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-49-6743-01Z-00-DX2//TCGA-49-6743-01Z-00-DX2_001/Ambiguous
# Sub image name:  /TCGA-49-6743-01Z-00-DX2_005
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-49-6743-01Z-00-DX2/TCGA-49-6743-01Z-00-DX2_005
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-49-6743-01Z-00-DX2//TCGA-49-6743-01Z-00-DX2_005/Ambiguous
# Sub image name:  /TCGA-49-6743-01Z-00-DX2_004
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-49-6743-01Z-00-DX2/TCGA-49-6743-01Z-00-DX2_004
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-49-6743-01Z-00-DX2//TCGA-49-6743-01Z-00-DX2_004/Ambiguous
# Sub image name:  /TCGA-49-6743-01Z-00-DX2_002
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-49-6743-01Z-00-DX2/TCGA-49-6743-01Z-00-DX2_002
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-49-6743-01Z-00-DX2//TCGA-49-6743-01Z-00-DX2_002/Ambiguous
# Patient name:  TCGA-VP-A87H-01Z-00-DX1
# Sub image name:  /TCGA-VP-A87H-01Z-00-DX1_5
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-VP-A87H-01Z-00-DX1/TCGA-VP-A87H-01Z-00-DX1_5
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-VP-A87H-01Z-00-DX1//TCGA-VP-A87H-01Z-00-DX1_5/Ambiguous
# Sub image name:  /TCGA-VP-A87H-01Z-00-DX1_1
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-VP-A87H-01Z-00-DX1/TCGA-VP-A87H-01Z-00-DX1_1
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-VP-A87H-01Z-00-DX1//TCGA-VP-A87H-01Z-00-DX1_1/Ambiguous
# Sub image name:  /TCGA-VP-A87H-01Z-00-DX1_6
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-VP-A87H-01Z-00-DX1/TCGA-VP-A87H-01Z-00-DX1_6
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-VP-A87H-01Z-00-DX1//TCGA-VP-A87H-01Z-00-DX1_6/Ambiguous
# Sub image name:  /TCGA-VP-A87H-01Z-00-DX1_2
# /home/dm1/shikhar/check_sandbox/testing_code/test_output_1/TCGA-VP-A87H-01Z-00-DX1/TCGA-VP-A87H-01Z-00-DX1_2
# 	Ambi Path:  /home/dm1/shikhar/check_sandbox/testing_code/MoNuSAC_testing_data/MoNuSAC_testing_ambiguous_regions/TCGA-VP-A87H-01Z-00-DX1//TCGA-VP-A87H-01Z-00-DX1_2/Ambiguous
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-792c920c8e76> in <module>
#      89                 plt.imshow(l, 'gray', interpolation='none')
#      90                 plt.imshow(ambi, 'Paired', interpolation='none', alpha=0.7)
# ---> 91                 plt.savefig(sub_image + '/Lymphocyte' + '/fig.png')
#      92
#      93                 plt.imshow(m, 'gray', interpolation='none')
#
# ~/miniconda3/envs/opencv1/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     727 def savefig(*args, **kwargs):
#     728     fig = gcf()
# --> 729     res = fig.savefig(*args, **kwargs)
#     730     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     731     return res
#
# ~/miniconda3/envs/opencv1/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# ~/miniconda3/envs/opencv1/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2089                     orientation=orientation,
#    2090                     bbox_inches_restore=_bbox_inches_restore,
# -> 2091                     **kwargs)
#    2092             finally:
#    2093                 if bbox_inches and restore_bbox:
#
# ~/miniconda3/envs/opencv1/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# ~/miniconda3/envs/opencv1/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/miniconda3/envs/opencv1/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/opencv1/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/miniconda3/envs/opencv1/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/miniconda3/envs/opencv1/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/opencv1/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~/miniconda3/envs/opencv1/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/miniconda3/envs/opencv1/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/opencv1/lib/python3.6/site-packages/matplotlib/image.py in draw(self, renderer, *args, **kwargs)
#     617         else:
#     618             im, l, b, trans = self.make_image(
# --> 619                 renderer, renderer.get_image_magnification())
#     620             if im is not None:
#     621                 renderer.draw_image(gc, l, b, im)
#
# ~/miniconda3/envs/opencv1/lib/python3.6/site-packages/matplotlib/image.py in make_image(self, renderer, magnification, unsampled)
#     879         return self._make_image(
#     880             self._A, bbox, transformed_bbox, self.axes.bbox, magnification,
# --> 881             unsampled=unsampled)
#     882
#     883     def _check_unsampled_image(self, renderer):
#
# ~/miniconda3/envs/opencv1/lib/python3.6/site-packages/matplotlib/image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     429                                 self.get_resample(), 1.0,
#     430                                 self.get_filternorm(),
# --> 431                                 self.get_filterrad())
#     432
#     433                 # we are done with A_scaled now, remove from namespace
#
# KeyboardInterrupt:
